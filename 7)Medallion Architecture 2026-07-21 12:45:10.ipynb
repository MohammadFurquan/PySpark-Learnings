# %% [markdown]
# # Data Warehouse vs Data Lake
#
# Both are used to store data, but they serve different purposes.
#
# ---
#
# # What is a Data Warehouse?
#
# A **Data Warehouse** is a centralized repository designed for storing **structured and processed data** for reporting, analytics, and business intelligence.
#
# Think of it as:
#
# ```text
# Clean Data
#      ↓
# Reporting
#      ↓
# Business Decisions
# ```
#
# ### Examples
#
# - Snowflake
# - Amazon Redshift
# - Azure Synapse
# - Google BigQuery
# - Teradata
#
# ---
#
# ## Data Warehouse Characteristics
#
# ✅ Structured data only
#
# ✅ Schema enforced before loading data
#
# ✅ Fast SQL queries
#
# ✅ Optimized for reporting
#
# ✅ Supports ACID transactions
#
# ❌ Expensive storage
#
# ❌ Not ideal for unstructured data
#
# ---
#
# ## Example
#
# Suppose an e-commerce company wants to analyze:
#
# ```text
# Daily Sales
# Monthly Revenue
# Top Products
# Customer Trends
# ```
#
# Data is first cleaned and transformed:
#
# ```text
# Raw Data
#     ↓
# ETL Process
#     ↓
# Data Warehouse
#     ↓
# Power BI / Tableau
# ```
#
# Example Query:
#
# ```sql
# SELECT region, SUM(sales)
# FROM sales
# GROUP BY region;
# ```
#
# ---
#
# ## When to Use a Data Warehouse?
#
# Use a Data Warehouse when:
#
# ✅ Data is already cleaned
#
# ✅ Mostly structured data
#
# ✅ Business reporting is the main requirement
#
# ✅ Fast SQL analytics is required
#
# ✅ Dashboards and KPIs need to be generated
#
# ---
#
# # What is a Data Lake?
#
# A **Data Lake** is a storage repository that can store **structured, semi-structured, and unstructured data** in its raw format.
#
# Think of it as:
#
# ```text
# Store Everything First
# Analyze Later
# ```
#
# ### Examples
#
# - Amazon S3
# - Azure Data Lake Storage (ADLS)
# - Google Cloud Storage (GCS)
#
# ---
#
# ## Data Lake Characteristics
#
# ✅ Stores any type of data
#
# ✅ Cheap storage
#
# ✅ Massive scalability
#
# ✅ Ideal for big data and ML
#
# ✅ Schema applied during reading
#
# ❌ Slower analytics compared to warehouses
#
# ❌ Governance can be challenging
#
# ---
#
# ## Example
#
# An e-commerce company collects:
#
# ```text
# Sales Data
# Customer Data
# Application Logs
# JSON Files
# Images
# Videos
# Clickstream Data
# ```
#
# All data is stored directly in the Data Lake.
#
# ```text
# Raw Data
#      ↓
# Data Lake (S3 / ADLS)
# ```
#
# No need to transform data before storing it.
#
# ---
#
# ## When to Use a Data Lake?
#
# Use a Data Lake when:
#
# ✅ You need to store raw data
#
# ✅ Data comes from multiple sources
#
# ✅ You have unstructured data
#
# ✅ Building ML/AI solutions
#
# ✅ Long-term data storage is needed
#
# ✅ Cost-effective storage is important
#
# ---
#
# # Real-Life Example
#
# ## Data Warehouse Example
#
# Bank Management System
#
# ```text
# Transactions
# Customers
# Loans
# Branches
# ```
#
# Business users need reports:
#
# ```text
# Monthly Revenue
# Branch Performance
# Customer Growth
# ```
#
# Use:
#
# ```text
# Data Warehouse
# ```
#
# Because data is structured and reporting-focused.
#
# ---
#
# ## Data Lake Example
#
# Netflix / YouTube
#
# They collect:
#
# ```text
# Video Metadata
# User Clicks
# Watch History
# Logs
# Images
# Videos
# ```
#
# Use:
#
# ```text
# Data Lake
# ```
#
# Because huge amounts of structured and unstructured data need to be stored.
#
# ---
#
# # Data Warehouse vs Data Lake
#
# | Feature | Data Warehouse | Data Lake |
# |----------|----------|----------|
# | Data Type | Structured | Structured, Semi-Structured, Unstructured |
# | Data Quality | Cleaned and Processed | Raw Data |
# | Storage Cost | Higher | Lower |
# | Query Performance | Fast | Slower |
# | Best For | Reporting & BI | Big Data & ML |
# | Schema | Schema-on-Write | Schema-on-Read |
# | Users | Business Analysts | Data Engineers & Data Scientists |
#
# ---
#
# # Easy Analogy
#
# ### Data Warehouse
#
# Like a supermarket shelf:
#
# ```text
# Products are already organized
# Easy to find and use
# ```
#
# ---
#
# ### Data Lake
#
# Like a warehouse storage room:
#
# ```text
# Everything is stored
# Organization happens when needed
# ```
#
# ---
#
# # Interview Answer
#
# > A Data Warehouse is a system designed to store structured, cleaned, and processed data optimized for reporting, business intelligence, and SQL analytics. Examples include Snowflake, Redshift, and Azure Synapse.
# >
# > A Data Lake is a highly scalable storage repository that stores structured, semi-structured, and unstructured data in its raw format. Examples include Amazon S3, Azure Data Lake Storage, and Google Cloud Storage.
# >
# > Data Warehouses are typically used for reporting and business analytics, while Data Lakes are used for big data processing, machine learning, and storing large volumes of raw data from multiple sources.

# %%
print("*****************************************************************")

# %% [markdown]
# # Schema-on-Write vs Schema-on-Read
#
# The main difference is **when the schema is applied and validated**.
#
# ---
#
# # Schema-on-Write
#
# Schema-on-Write means:
#
# > Data is validated against a predefined schema **before it is stored**.
#
# ### Flow
#
# ```text
# Data
#  ↓
# Schema Validation
#  ↓
# Store Data
# ```
#
# ### Example
#
# Expected Schema:
#
# ```text
# id      → Integer
# name    → String
# salary  → Double
# ```
#
# Incoming Data:
#
# ```text
# id = 101
# name = Arif
# salary = "abc"
# ```
#
# Since `salary` should be a Double but a String is received, the data will be rejected.
#
# ### Advantages
#
# ✅ High data quality
#
# ✅ Consistent data
#
# ✅ Reliable reporting
#
# ✅ Faster analytics
#
# ### Used In
#
# ```text
# Data Warehouses
# ```
#
# Examples:
#
# - Snowflake
# - Amazon Redshift
# - Azure Synapse
# - SQL Server
#
# ---
#
# # Schema-on-Read
#
# Schema-on-Read means:
#
# > Data is stored first, and the schema is applied only when the data is read.
#
# ### Flow
#
# ```text
# Data
#  ↓
# Store Data
#  ↓
# Read Data
#  ↓
# Apply Schema
# ```
#
# ### Example
#
# Incoming Data:
#
# ```json
# {
#   "id": 101,
#   "name": "Arif",
#   "salary": "abc"
# }
# ```
#
# The data is stored successfully in the Data Lake.
#
# Later, while reading:
#
# ```python
# spark.read.schema(my_schema).json("/data")
# ```
#
# Spark attempts to apply the schema at read time.
#
# ### Advantages
#
# ✅ Very flexible
#
# ✅ Can store any type of data
#
# ✅ Suitable for Big Data workloads
#
# ✅ Great for Data Science and Machine Learning
#
# ### Used In
#
# ```text
# Data Lakes
# ```
#
# Examples:
#
# - Amazon S3
# - Azure Data Lake Storage (ADLS)
# - Google Cloud Storage (GCS)
#
# ---
#
# # Easy Real-Life Analogy
#
# ## Schema-on-Write (Airport Security)
#
# ```text
# First Security Check
#          ↓
# Then Entry
# ```
#
# Only valid passengers are allowed inside.
#
# Similar to:
#
# ```text
# Validate Data
#       ↓
# Store Data
# ```
#
# ---
#
# ## Schema-on-Read (Warehouse/Godown)
#
# ```text
# Store Everything
#         ↓
# Organize Later
# ```
#
# Similar to:
#
# ```text
# Store Data
#       ↓
# Apply Schema During Read
# ```
#
# ---
#
# # Data Warehouse vs Data Lake
#
# ```text
# Data Warehouse
#         ↓
# Schema-on-Write
#
# Data Lake
#         ↓
# Schema-on-Read
# ```
#
# ---
#
# # What About Databricks Delta Lake?
#
# Databricks combines the benefits of both approaches.
#
# ```text
# Data Lake Flexibility
#           +
# Data Warehouse Reliability
#           =
# Lakehouse
# ```
#
# Delta Lake provides:
#
# ✅ Schema Enforcement
#
# ✅ ACID Transactions
#
# ✅ Time Travel
#
# ✅ Data Governance
#
# ✅ High Performance
#
# This is why Databricks is called a **Lakehouse Platform**.
#
# ---
#
# # Interview Answer
#
# > Schema-on-Write means data is validated against a predefined schema before it is stored. Invalid data is rejected, ensuring high data quality and consistency. It is commonly used in Data Warehouses.
# >
# > Schema-on-Read means raw data is stored first, and the schema is applied only when the data is read for analysis. This provides flexibility and is commonly used in Data Lakes. Modern Lakehouse platforms like Databricks Delta Lake combine the advantages of both approaches.

# %%
print("*****************************************************")

# %% [markdown]
# # What is a Data Lakehouse?
#
# A **Data Lakehouse** is a modern data architecture that combines the best features of both:
#
# - **Data Lakes**
# - **Data Warehouses**
#
# It provides the flexibility and low cost of a Data Lake while also offering the reliability, governance, and performance of a Data Warehouse.
#
# ---
#
# ## Evolution of Data Platforms
#
# ```text
# Traditional Database
#         ↓
# Data Warehouse
#         ↓
# Data Lake
#         ↓
# Data Lakehouse
# ```
#
# ---
#
# # Data Warehouse
#
# A Data Warehouse stores:
#
# ✅ Structured data
#
# ✅ Cleaned and processed data
#
# ✅ Supports BI and Reporting
#
# Examples:
#
# ```text
# Snowflake
# Teradata
# Amazon Redshift
# Azure Synapse
# ```
#
# ### Advantages
#
# - Fast SQL queries
# - ACID transactions
# - Good governance
#
# ### Limitations
#
# - Expensive
# - Doesn't handle unstructured data well
#
# ---
#
# # Data Lake
#
# A Data Lake stores:
#
# ✅ Structured data
#
# ✅ Semi-structured data
#
# ✅ Unstructured data
#
# Examples:
#
# ```text
# S3
# ADLS
# GCS
# ```
#
# ### Advantages
#
# - Cheap storage
# - Highly scalable
# - Can store any data type
#
# ### Limitations
#
# - Poor governance
# - Data quality issues
# - No transaction guarantees
# - Difficult for BI workloads
#
# ---
#
# # Data Lakehouse
#
# A Data Lakehouse combines both approaches.
#
# ```text
# Data Lake
#     +
# Data Warehouse
#     =
# Data Lakehouse
# ```
#
# ### Provides
#
# ✅ Low-cost storage
#
# ✅ ACID transactions
#
# ✅ Schema enforcement
#
# ✅ Governance
#
# ✅ BI reporting
#
# ✅ Machine Learning support
#
# ✅ Streaming support
#
# ---
#
# # Data Lakehouse Architecture
#
# ```text
#                 BI Tools
#             (Power BI, Tableau)
#                     |
#                     |
#               SQL Queries
#                     |
#                     |
#         -----------------------
#         |     Lakehouse       |
#         -----------------------
#           |       |       |
#           |       |       |
#      Batch    Streaming   ML
#           \       |      /
#            \      |     /
#             \     |    /
#              Data Lake
#         (S3, ADLS, GCS)
# ```
#
# ---
#
# # Key Features of a Data Lakehouse
#
# ## 1. ACID Transactions
#
# Supports:
#
# ```sql
# INSERT
# UPDATE
# DELETE
# MERGE
# ```
#
# Example:
#
# ```sql
# MERGE INTO customers
# USING updates
# ON customers.id = updates.id
# ```
#
# ✅ Reliable data updates
#
# ✅ Data consistency
#
# ---
#
# ## 2. Schema Enforcement
#
# Prevents bad data from being written.
#
# Example:
#
# ```text
# Expected:
# age → Integer
#
# Incoming:
# age → String
# ```
#
# Lakehouse can reject invalid data.
#
# ✅ Better data quality
#
# ---
#
# ## 3. Time Travel
#
# View historical versions of a table.
#
# Example:
#
# ```sql
# SELECT * FROM customers VERSION AS OF 5;
# ```
#
# ✅ Easy auditing
#
# ✅ Recovery from mistakes
#
# ---
#
# ## 4. Data Governance
#
# Supports:
#
# - Role-based access control
# - Column-level security
# - Row-level security
# - Auditing
#
# ✅ Enterprise-grade security
#
# ---
#
# ## 5. Supports All Data Types
#
# ```text
# Structured
# Semi-Structured
# Unstructured
# ```
#
# Examples:
#
# ```text
# CSV
# JSON
# Parquet
# Images
# Videos
# Logs
# ```
#
# ---
#
# # Databricks Lakehouse
#
# Databricks implements the Lakehouse architecture using:
#
# ## Delta Lake
#
# Provides:
#
# ✅ ACID Transactions
#
# ✅ Time Travel
#
# ✅ Schema Enforcement
#
# ✅ MERGE Operations
#
# ---
#
# ## Unity Catalog
#
# Provides:
#
# ✅ Centralized Governance
#
# ✅ Access Control
#
# ✅ Auditing
#
# ✅ Data Discovery
#
# ---
#
# # Why Companies Prefer Lakehouse?
#
# Instead of maintaining:
#
# ```text
# Data Lake
# +
# Data Warehouse
# +
# ML Platform
# ```
#
# Companies can use:
#
# ```text
# One Unified Platform
# ```
#
# Benefits:
#
# ✅ Lower cost
#
# ✅ Less data duplication
#
# ✅ Easier governance
#
# ✅ Simplified architecture
#
# ---
#
# # Real-World Example
#
# A company stores:
#
# ```text
# Sales Data
# Customer Data
# Application Logs
# Images
# Streaming Events
# ```
#
# in:
#
# ```text
# ADLS / S3
# ```
#
# Using Delta Lake and Databricks:
#
# ```text
# Store Data
#       ↓
# Process Data
#       ↓
# Run SQL Analytics
#       ↓
# Build Dashboards
#       ↓
# Train ML Models
# ```
#
# All on the same platform.
#
# ---
#
# # Interview Answer
#
# > A Data Lakehouse is a modern data architecture that combines the scalability and low-cost storage of a Data Lake with the reliability, performance, governance, and ACID transaction capabilities of a Data Warehouse. It enables organizations to store structured, semi-structured, and unstructured data in a single platform while supporting analytics, reporting, streaming, and machine learning workloads. Databricks implements the Lakehouse architecture using Delta Lake and Unity Catalog.

# %%
print("*********************** MEDALLION ARCHITECTURE ***********************")

# %% [markdown]
# # What is Medallion Architecture?
#
# **Medallion Architecture** is a data design pattern used in Databricks and Data Engineering to organize data into multiple layers that gradually improve data quality.
#
# The data typically moves through:
#
# ```text
# Bronze Layer
#      ↓
# Silver Layer
#      ↓
# Gold Layer
# ```
#
# As data moves from Bronze → Silver → Gold:
#
# ✅ Data quality improves
#
# ✅ Data becomes more business-ready
#
# ✅ Easier governance and maintenance
#
# ✅ Better performance
#
# ---
#
# # Why Do We Need Medallion Architecture?
#
# Suppose data is coming from:
#
# ```text
# CSV Files
# JSON Files
# APIs
# Databases
# Streaming Sources
# ```
#
# Raw data may contain:
#
# ```text
# Duplicates
# Null Values
# Incorrect Records
# Bad Formats
# Missing Data
# ```
#
# Instead of directly exposing raw data to business users, we process it through layers.
#
# ---
#
# # Bronze Layer (Raw Data)
#
# The Bronze layer stores data exactly as received from the source.
#
# ### Characteristics
#
# ✅ Raw data
#
# ✅ No transformations
#
# ✅ Historical data retained
#
# ✅ Used for auditing and reprocessing
#
# ### Example
#
# Source Data:
#
# ```text
# id,name,salary
# 1,Arif,50000
# 2,Rahul,NULL
# 3,Amit,ABC
# ```
#
# Stored exactly as received.
#
# ```text
# Raw Data
#      ↓
# Bronze Table
# ```
#
# ### Purpose
#
# > Never lose the original source data.
#
# ---
#
# # Silver Layer (Cleaned Data)
#
# The Silver layer contains cleaned and validated data.
#
# ### Operations Performed
#
# ✅ Remove duplicates
#
# ✅ Handle null values
#
# ✅ Data validation
#
# ✅ Standardize formats
#
# ✅ Join datasets
#
# ✅ Apply business rules
#
# ### Example
#
# Bronze:
#
# ```text
# 1,Arif,50000
# 2,Rahul,NULL
# 3,Amit,ABC
# ```
#
# Silver:
#
# ```text
# 1,Arif,50000
# ```
#
# Invalid records removed or corrected.
#
# ### Purpose
#
# > Create trusted and high-quality datasets.
#
# ---
#
# # Gold Layer (Business-Ready Data)
#
# The Gold layer contains aggregated and business-friendly data.
#
# ### Operations Performed
#
# ✅ Aggregations
#
# ✅ KPIs
#
# ✅ Business metrics
#
# ✅ Reporting tables
#
# ✅ Dashboard tables
#
# ### Example
#
# Silver Data:
#
# ```text
# Customer Transactions
# ```
#
# Gold Data:
#
# ```text
# Region     Total Sales
# North      1,000,000
# South        750,000
# East         500,000
# ```
#
# ### Purpose
#
# > Provide data for reports, dashboards, and business users.
#
# ---
#
# # Data Flow
#
# ```text
# Source Systems
#       ↓
#    Bronze
# (Raw Data)
#       ↓
#    Silver
# (Cleaned Data)
#       ↓
#     Gold
# (Business Ready Data)
# ```
#
# ---
#
# # Real-World Example
#
# ### E-Commerce Company
#
# Incoming Data:
#
# ```text
# Orders
# Customers
# Payments
# Products
# ```
#
# ### Bronze
#
# ```text
# Raw Orders Data
# Raw Customer Data
# Raw Payment Data
# ```
#
# ### Silver
#
# ```text
# Clean Orders
# Validated Customers
# Deduplicated Payments
# ```
#
# ### Gold
#
# ```text
# Daily Sales Report
# Top Products Report
# Customer Analytics
# Revenue Dashboard
# ```
#
# ---
#
# # When Do We Use Medallion Architecture?
#
# Use Medallion Architecture when:
#
# ✅ Building Data Lakes or Lakehouses
#
# ✅ Processing large volumes of data
#
# ✅ Multiple teams consume data
#
# ✅ Data quality is important
#
# ✅ Building reporting and analytics solutions
#
# ✅ Creating scalable ETL/ELT pipelines
#
# ✅ Using Databricks + Delta Lake
#
# ---
#
# # Benefits
#
# ### 1. Better Data Quality
#
# ```text
# Bronze → Raw
# Silver → Clean
# Gold → Trusted
# ```
#
# ---
#
# ### 2. Easier Debugging
#
# If an issue occurs:
#
# ```text
# Gold
#  ↓
# Silver
#  ↓
# Bronze
# ```
#
# You can trace where the problem originated.
#
# ---
#
# ### 3. Data Reusability
#
# Different teams can use:
#
# ```text
# Silver Tables
# ```
#
# for analytics and
#
# ```text
# Gold Tables
# ```
#
# for reporting.
#
# ---
#
# ### 4. Better Governance
#
# Each layer has a clear purpose:
#
# ```text
# Bronze = Raw
# Silver = Cleansed
# Gold = Business
# ```
#
# ---
#
# ### 5. Scalability
#
# Works well for:
#
# ```text
# Batch Processing
# Streaming
# Big Data Workloads
# Machine Learning
# Analytics
# ```
#
# ---
#
# # Interview Answer
#
# > Medallion Architecture is a data design pattern used in Databricks and Lakehouse environments to progressively improve data quality through multiple layers. It consists of Bronze, Silver, and Gold layers. The Bronze layer stores raw source data, the Silver layer contains cleaned and validated data, and the Gold layer contains aggregated, business-ready datasets used for reporting and analytics. Medallion Architecture improves data quality, governance, reusability, scalability, and simplifies debugging and maintenance of data pipelines.

# %% [markdown]
# # Medallion Architecture Example (Sales Data)
#
# Suppose a retail company receives daily sales data.
#
# ## Raw Sales Data
#
# ```text
# order_id | customer | product | quantity | amount | order_date
# ----------------------------------------------------------------
# 101      | Arif     | Laptop  | 1        | 50000  | 2025-01-01
# 102      | Rahul    | Mouse   | 2        | 1000   | 2025-01-01
# 102      | Rahul    | Mouse   | 2        | 1000   | 2025-01-01   <-- Duplicate
# 103      | Amit     | Keyboard| 1        | NULL   | 2025-01-01
# 104      | John     | Laptop  | 1        | ABC    | 2025-01-01
# ```
#
# ---
#
# # Bronze Layer (Raw Data)
#
# ### What do we do?
#
# Almost nothing 😄
#
# We simply ingest the data as-is.
#
# ```text
# Source File
#       ↓
# Bronze Table
# ```
#
# ### Data Stored
#
# ```text
# 101 | Arif  | Laptop   | 1 | 50000 | 2025-01-01
# 102 | Rahul | Mouse    | 2 | 1000  | 2025-01-01
# 102 | Rahul | Mouse    | 2 | 1000  | 2025-01-01
# 103 | Amit  | Keyboard | 1 | NULL  | 2025-01-01
# 104 | John  | Laptop   | 1 | ABC   | 2025-01-01
# ```
#
# ### Purpose
#
# ✅ Keep original source data
#
# ✅ Enable reprocessing later
#
# ✅ Audit and compliance
#
# Think:
#
# > Bronze = "Store everything, don't modify anything."
#
# ---
#
# # Silver Layer (Cleaned Data)
#
# ### What do we do?
#
# Data cleansing and validation.
#
# Operations:
#
# - Remove duplicates
# - Handle NULL values
# - Fix data types
# - Standardize formats
# - Apply business rules
#
# ### Example
#
# Before:
#
# ```text
# 102 | Rahul | Mouse | 2 | 1000 | 2025-01-01
# 102 | Rahul | Mouse | 2 | 1000 | 2025-01-01
# ```
#
# Duplicate removed.
#
# Before:
#
# ```text
# 103 | Amit | Keyboard | 1 | NULL
# ```
#
# Handled using business rule.
#
# Before:
#
# ```text
# 104 | John | Laptop | 1 | ABC
# ```
#
# Invalid amount removed or corrected.
#
# ### Silver Output
#
# ```text
# 101 | Arif  | Laptop   | 1 | 50000 | 2025-01-01
# 102 | Rahul | Mouse    | 2 | 1000  | 2025-01-01
# ```
#
# ### Purpose
#
# ✅ Trusted data
#
# ✅ Clean data
#
# ✅ Used by data engineers and analysts
#
# Think:
#
# > Silver = "Clean and validated data."
#
# ---
#
# # Gold Layer (Business Ready Data)
#
# ### What do we do?
#
# Create business metrics and aggregations.
#
# Example:
#
# Business asks:
#
# > Show total sales by product.
#
# Using Silver data:
#
# ```text
# Laptop = 50000
# Mouse  = 1000
# ```
#
# Gold Table:
#
# ```text
# product  | total_sales
# ----------------------
# Laptop   | 50000
# Mouse    | 1000
# ```
#
# Another Gold table:
#
# ```text
# sales_date | total_revenue
# ---------------------------
# 2025-01-01 | 51000
# ```
#
# ### Purpose
#
# ✅ Dashboards
#
# ✅ KPIs
#
# ✅ Power BI
#
# ✅ Reporting
#
# ✅ Executive summaries
#
# Think:
#
# > Gold = "Data ready for business users."
#
# ---
#
# # Complete Flow
#
# ```text
# Raw Sales File
#        ↓
#
# BRONZE
# -------
# Store Raw Data
# (No Transformations)
#
#        ↓
#
# SILVER
# -------
# Remove Duplicates
# Handle Nulls
# Fix Data Types
# Apply Business Rules
#
#        ↓
#
# GOLD
# -------
# Daily Sales
# Revenue KPIs
# Product Analytics
# Management Reports
# ```
#
# ---
#
# # Easy Interview Answer
# > In a sales use case, the Bronze layer stores raw sales transactions exactly as received from source systems. The Silver layer cleans the data by removing duplicates, handling null values, correcting data types, and applying business rules. The Gold layer contains business-ready data such as total sales, revenue KPIs, customer analytics, and dashboard tables that are consumed by business users and reporting tools like Power BI.

# %%
print("********************** TERMS ***********************")
