# %%
df = spark.read.csv("/Volumes/workspace/default/raw_data/orders.csv")
display(df)
# header is taken as the first row of the table

# %%
# Added header eariler it was considering it as a row
df = spark.read \
    .option("header", True) \
    .csv("/Volumes/workspace/default/raw_data/orders.csv")
display(df)

# %%
df.printSchema()
# qty and price is string

# %%
df = spark.read \
    .option("inferSchema", True) \
    .option("header", True) \
    .csv("/Volumes/workspace/default/raw_data/orders.csv")
display(df)

# %%
df.printSchema()
# qty and price is integer and double respectively because of inferSchema

# %%
from pyspark.sql import functions as F, types as T
csv_schema = T.StructType([
    T.StructField("order_date", T.DateType(),   True),
    T.StructField("country",    T.StringType(), True),
    T.StructField("order_id",   T.IntegerType(),True),
    T.StructField("product",    T.StringType(), True),
    T.StructField("qty",        T.IntegerType(),True),
    T.StructField("price",      T.DoubleType(), True),
])

# %%
df = spark.read \
    .option("inferSchema", True) \
    .schema(csv_schema) \
    .csv("/Volumes/workspace/default/raw_data/orders.csv")
display(df)

# %%
# code of own schema there are 2 types
# 1) using StructType
# 2) using DDL
# explore that

# %%
df = spark.read \
    .schema(csv_schema) \
    .option("dateFormat", "MM-dd-yyyy") \
    .option("header", True) \
    .csv("/Volumes/workspace/default/raw_data/orders.csv")
display(df)

# %%
# instead of writing .csv() we can write .format("csv") but at last we must have to give path in .load("/Volumes/workspace/default/raw_data/orders.csv")

df = spark.read \
    .format('csv') \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/default/raw_data/orders.csv")
display(df)
# we can also write it like this

# %%
# Write in parquet format
df.write.mode("overwrite").parquet("/Volumes/workspace/default/raw_data/orders")
