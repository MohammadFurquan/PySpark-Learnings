# %% [markdown]
# # What is Unity Catalog in Databricks?
#
# **Unity Catalog** is Databricks' centralized data governance solution.
#
# It helps organizations manage:
#
# ✅ Data Access
#
# ✅ Security
#
# ✅ Permissions
#
# ✅ Auditing
#
# ✅ Data Discovery
#
# ✅ Data Governance
#
# across all data and AI assets from a single place.
#
# Think of Unity Catalog as:
#
# ```text
# The Central Control Center
# for all data in Databricks
# ```
#
# ---
#
# # Why Was Unity Catalog Introduced?
#
# Without Unity Catalog:
#
# ```text
# Team A → Own Security Rules
# Team B → Own Security Rules
# Team C → Own Security Rules
# ```
#
# Managing permissions becomes difficult.
#
# With Unity Catalog:
#
# ```text
# One Central Governance Layer
#            ↓
# Controls Everything
# ```
#
# ---
#
# # Unity Catalog Hierarchy
#
# Unity Catalog follows a 3-level namespace:
#
# ```text
# Catalog
#    ↓
# Schema
#    ↓
# Table/View
# ```
#
# Example:
#
# ```text
# company_data
#      ↓
# sales
#      ↓
# transactions
# ```
#
# Reference:
#
# ```sql
# SELECT *
# FROM company_data.sales.transactions;
# ```
#
# ---
#
# # Unity Catalog Object Structure
#
# ```text
# Metastore
#     ↓
# Catalog
#     ↓
# Schema
#     ↓
# Table/View
# ```
#
# ### Example
#
# ```text
# Metastore
#    ↓
# sales_catalog
#    ↓
# sales_schema
#    ↓
# orders_table
# ```
#
# ---
#
# # Key Features of Unity Catalog
#
# ## 1. Centralized Access Control
#
# Grant permissions at different levels.
#
# ### Example
#
# ```sql
# GRANT SELECT
# ON TABLE sales.orders
# TO analysts;
# ```
#
# Result:
#
# ```text
# Analysts can read the table
# But cannot modify it
# ```
#
# ---
#
# ## 2. Fine-Grained Security
#
# Supports:
#
# ### Table-Level Security
#
# ```text
# User can access specific tables only.
# ```
#
# ### Column-Level Security
#
# Example:
#
# ```text
# customer_id
# customer_name
# salary
# ```
#
# Hide:
#
# ```text
# salary
# ```
#
# from certain users.
#
# ### Row-Level Security
#
# Example:
#
# ```text
# North Region User
# ```
#
# can view only:
#
# ```text
# North Region Data
# ```
#
# ---
#
# ## 3. Data Discovery
#
# Users can easily find datasets.
#
# Example:
#
# ```text
# Available Catalogs
# Available Schemas
# Available Tables
# Data Owners
# Descriptions
# ```
#
# This creates a searchable data catalog.
#
# ---
#
# ## 4. Data Lineage
#
# Unity Catalog tracks:
#
# ```text
# Where data came from
# Where data is used
# What transformations happened
# ```
#
# Example:
#
# ```text
# Raw Orders
#       ↓
# Silver Orders
#       ↓
# Gold Sales Report
# ```
#
# You can visually trace the entire flow.
#
# ---
#
# ## 5. Auditing
#
# Unity Catalog records:
#
# ```text
# Who accessed data
# Who modified data
# Who granted permissions
# ```
#
# Useful for:
#
# ✅ Compliance
#
# ✅ Security
#
# ✅ Regulatory requirements
#
# ---
#
# ## 6. Works Across All Workspaces
#
# Without Unity Catalog:
#
# ```text
# Workspace A
# Workspace B
# Workspace C
# ```
#
# all manage permissions separately.
#
# With Unity Catalog:
#
# ```text
# One Governance

# %%
print("********************************")

# %%
# In Databricks --> Catalog --> Default Catalog is there that is "Workspace"
# We can also create our own catalog, just click on +
# then create a catalog --> Enter catalog name like sales, marketing
# then within catalog --> inside catalog schema is there inside schema table and volumes are there
# Catalog --> Schema --> Table/Volume
# Click on any catalog name like workspace in right side it will opened click on "Permission" -> you can grant/revoke permissions to group/user

# then in scheam also we can grant/user permission to group/user
# then in table/volume also we can grant/user permission to group/user
# Thats why we say Unity Catalog gives Fine-Grained Security.
# and it also provides lineage same as in spark.

# In Tables in details we can add "Tag" for searching easily

# %%
print("************************ ACID ************************")

# %% [markdown]
# # ACID Properties in Databricks (Delta Lake)
#
# ACID properties ensure that data remains **accurate, consistent, and reliable** even when multiple users or jobs are reading and writing data simultaneously.
#
# Databricks provides ACID transactions through **Delta Lake**.
#
# ---
#
# # What Does ACID Stand For?
#
# ```text
# A → Atomicity
# C → Consistency
# I → Isolation
# D → Durability
# ```
#
# ---
#
# # 1. Atomicity
#
# Atomicity means:
#
# > Either the entire transaction succeeds or the entire transaction fails.
#
# There is no partial update.
#
# ### Example
#
# Suppose a banking transaction transfers ₹1000:
#
# ```text
# Account A → -1000
# Account B → +1000
# ```
#
# Possible outcomes:
#
# ```text
# ✅ Both operations succeed
# ```
#
# or
#
# ```text
# ✅ Both operations are rolled back
# ```
#
# Not:
#
# ```text
# ❌ Account A debited
# ❌ Account B not credited
# ```
#
# ### Benefit
#
# ✅ Prevents partial writes
#
# ✅ Prevents data corruption
#
# ---
#
# # 2. Consistency
#
# Consistency means:
#
# > Data always remains in a valid state before and after a transaction.
#
# ### Example
#
# Table Rule:
#
# ```text
# salary > 0
# ```
#
# Invalid Data:
#
# ```text
# salary = -5000
# ```
#
# Such invalid records should not violate business rules and constraints.
#
# ### Benefit
#
# ✅ Maintains data integrity
#
# ✅ Ensures valid data
#
# ---
#
# # 3. Isolation
#
# Isolation means:
#
# > Multiple transactions can run simultaneously without interfering with each other.
#
# ### Example
#
# Two users update the same table:
#
# ```text
# User A → Updating Data
# User B → Reading Data
# ```
#
# User B should not see incomplete or partially written data.
#
# ### Benefit
#
# ✅ Prevents dirty reads
#
# ✅ Prevents inconsistent results
#
# ✅ Supports concurrent users
#
# ---
#
# # 4. Durability
#
# Durability means:
#
# > Once a transaction is committed, it is permanently stored.
#
# Even if:
#
# ```text
# Cluster crashes
# System restarts
# Power failure occurs
# ```
#
# the committed data remains safe.
#
# ### Example
#
# ```sql
# INSERT INTO sales VALUES (101, 1000);
# ```
#
# Once committed:
#
# ```text
# ✅ Data is permanently saved
# ```
#
# ### Benefit
#
# ✅ Protects against data loss
#
# ✅ Reliable storage
#
# ---
#
# # ACID Example in Databricks
#
# Suppose a Delta table contains:
#
# ```text
# order_id | amount
# ------------------
# 101      | 1000
# 102      | 2000
# ```
#
# Update:
#
# ```sql
# UPDATE sales
# SET amount = 2500
# WHERE order_id = 102;
# ```
#
# Delta Lake ensures:
#
# ### Atomicity
#
# ```text
# Entire update succeeds
# OR
# Entire update fails
# ```
#
# ### Consistency
#
# ```text
# Table remains valid after update
# ```
#
# ### Isolation
#
# ```text
# Other users do not see partial updates
# ```
#
# ### Durability
#
# ```text
# Committed update remains saved permanently
# ```
#
# ---
#
# # Why ACID is Important in Databricks?
#
# Without ACID:
#
# ```text
# Multiple users writing data
#           ↓
# Corrupt Data
# Duplicate Data
# Partial Updates
# Incorrect Reports
# ```
#
# With ACID:
#
# ```text
# Reliable Data
# Consistent Reports
# Safe Concurrent Operations
# ```
#
# ---
#
# # Delta Lake and ACID Transactions
#
# Delta Lake provides:
#
# ✅ ACID Transactions
#
# ✅ Concurrent Reads and Writes
#
# ✅ Time Travel
#
# ✅ Schema Enforcement
#
# ✅ Data Reliability
#
# Operations such as:
#
# ```sql
# INSERT
# UPDATE
# DELETE
# MERGE
# ```
#
# are fully ACID compliant.
#
# ---
#
# # Real-World Example
#
# ### E-Commerce Company
#
# Users are:
#
# ```text
# Placing Orders
# Cancelling Orders
# Updating Payments
# Generating Reports
# ```
#
# all at the same time.
#
# ACID guarantees that:
#
# ```text
# Orders are not partially saved
# Reports show consistent data
# No data corruption occurs
# Completed transactions are permanent
# ```
#
# ---
#
# # Interview Answer
#
# > ACID stands for Atomicity, Consistency, Isolation, and Durability. In Databricks, Delta Lake provides ACID transaction support to ensure reliable and consistent data processing. Atomicity ensures transactions either fully succeed or fail, Consistency maintains valid data states, Isolation prevents concurrent transactions from interfering with each other, and Durability guarantees that committed data remains permanently stored even after failures. This enables safe `INSERT`, `UPDATE`, `DELETE`, and `MERGE` operations on Delta tables.

# %% [markdown]
# # What is Time Travel in Databricks?
#
# **Time Travel** is a Delta Lake feature that allows you to view or restore a table from a previous version.
#
# Think of it as:
#
# ```text
# Going back in time
# to see how the table looked earlier.
# ```
#
# ---
#
# # Why Do We Need Time Travel?
#
# Suppose your table contains:
#
# ```text
# id | name
# ----------
# 1  | Arif
# 2  | Rahul
# 3  | Amit
# ```
#
# Someone accidentally runs:
#
# ```sql
# DELETE FROM customers;
# ```
#
# Now all records are deleted.
#
# Normally:
#
# ```text
# Data Lost ❌
# ```
#
# But with Delta Lake Time Travel:
#
# ```text
# Data Can Be Recovered ✅
# ```
#
# because Delta keeps previous versions of the table.
#
# ---
#
# # How Time Travel Works
#
# Every operation creates a new version.
#
# ### Initial Table
#
# ```text
# Version 0
# ```
#
# | id | name |
# |----|------|
# | 1 | Arif |
# | 2 | Rahul |
#
# ---
#
# ### Insert New Record
#
# ```sql
# INSERT INTO customers VALUES (3, 'Amit');
# ```
#
# Creates:
#
# ```text
# Version 1
# ```
#
# | id | name |
# |----|------|
# | 1 | Arif |
# | 2 | Rahul |
# | 3 | Amit |
#
# ---
#
# ### Delete Record
#
# ```sql
# DELETE FROM customers WHERE id = 2;
# ```
#
# Creates:
#
# ```text
# Version 2
# ```
#
# | id | name |
# |----|------|
# | 1 | Arif |
# | 3 | Amit |
#
# ---
#
# Delta keeps:
#
# ```text
# Version 0
# Version 1
# Version 2
# ```
#
# ---
#
# # View Table History
#
# ```sql
# DESCRIBE HISTORY customers;
# ```
#
# Output:
#
# ```text
# Version
# 0
# 1
# 2
# ```
#
# along with:
#
# ```text
# Operation
# User
# Timestamp
# ```
#
# ---
#
# # Read Older Version
#
# Suppose current version is:
#
# ```text
# Version 2
# ```
#
# and you want to see:
#
# ```text
# Version 1
# ```
#
# ```sql
# SELECT *
# FROM customers VERSION AS OF 1;
# ```
#
# Result:
#
# ```text
# 1 | Arif
# 2 | Rahul
# 3 | Amit
# ```
#
# ---
#
# # Read Data by Timestamp
#
# Instead of version number:
#
# ```sql
# SELECT *
# FROM customers
# TIMESTAMP AS OF '2025-01-01 10:00:00';
# ```
#
# Delta returns the table exactly as it existed at that time.
#
# ---
#
# # Real-Life Example
#
# Suppose a Sales table contains:
#
# ```text
# 1000 Orders
# ```
#
# A developer accidentally executes:
#
# ```sql
# DELETE FROM sales;
# ```
#
# Current version:
#
# ```text
# Version 10
# ```
#
# Before deletion:
#
# ```text
# Version 9
# ```
#
# You can recover data using:
#
# ```sql
# SELECT *
# FROM sales VERSION AS OF 9;
# ```
#
# ---
#
# # Benefits of Time Travel
#
# ✅ Recover accidentally deleted data
#
# ✅ Audit historical changes(Historical Analysis)
#
# ✅ Compare old vs new data
#
# ✅ Debug data issues
#
# ✅ Reproduce old reports
#
# ✅ Support compliance requirements
#
# ---
#
# # Interview Answer
#
# > Time Travel is a Delta Lake feature that allows users to access and query previous versions of a table using a version number or timestamp. Every write operation creates a new version of the table, and Delta Lake maintains the transaction history. Time Travel is commonly used for data recovery, auditing, debugging, and analyzing historical data.

# %%
# Time travel is like a git, it maintains history after every write operation, and we can revert the commit like this here also we can do the same.


# Query data as it existed at versison 5
Select * from my_table VERSION AS OF 5

# Query data as it existed at a specific timestamp
Select * from my_table TIMESTAMP AS OF ‘2024-12-01 10:00:00’

# Restore table to previous version
RESTORE table my_table TO VERSION AS OF 10

# %% [markdown]
# **Delta lake is an open-source storage layer that brings ACID transactions, schema enforcement, and time travel capabilities to data lakes.**

# %% [markdown]
# # What is Delta Lake?
#
# **Delta Lake** is an open-source storage layer that brings Data Warehouse features to a Data Lake.
#
# It provides advanced capabilities such as:
#
# ✅ ACID Transactions
#
# ✅ Time Travel
#
# ✅ Schema Enforcement
#
# ✅ Audit History
#
# ✅ MERGE, UPDATE, and DELETE support
#
# ✅ Reliable and Consistent Data Processing
#
# ---
#
# # Why Do We Need Delta Lake?
#
# Without Delta Lake:
#
# ```text
# S3 / ADLS / GCS
#       ↓
#  Parquet Files
# ```
#
# You only have files stored in the Data Lake.
#
# Problems:
#
# ❌ No ACID transactions
#
# ❌ No Time Travel
#
# ❌ Difficult to handle concurrent writes
#
# ❌ Risk of data corruption
#
# ❌ Limited support for updates and deletes
#
# ---
#
# # How Delta Lake Solves These Problems
#
# Delta Lake adds a transaction log called:
#
# ```text
# _delta_log
# ```
#
# This log tracks:
#
# ```text
# Who modified the data
# When it was modified
# What was inserted
# What was updated
# What was deleted
# ```
#
# This makes data processing reliable and consistent.
#
# ---
#
# # Key Features of Delta Lake
#
# ## 1. ACID Transactions
#
# Delta Lake guarantees:
#
# ```text
# Atomicity
# Consistency
# Isolation
# Durability
# ```
#
# ### Example
#
# ```sql
# UPDATE sales
# SET amount = 1000
# WHERE id = 1;
# ```
#
# Possible outcomes:
#
# ```text
# ✅ Complete Update
# ```
#
# or
#
# ```text
# ✅ Complete Rollback
# ```
#
# Never:
#
# ```text
# ❌ Partial Update
# ```
#
# ---
#
# ## 2. Time Travel
#
# Delta Lake stores table history and versions.
#
# Example:
#
# ```sql
# SELECT *
# FROM sales VERSION AS OF 5;
# ```
#
# This allows you to view how the table looked in Version 5.
#
# ### Benefits
#
# ✅ Recover accidentally deleted data
#
# ✅ Audit changes
#
# ✅ Compare historical data
#
# ✅ Reproduce old reports
#
# ---
#
# ## 3. Schema Enforcement
#
# Expected Schema:
#
# ```text
# salary → Double
# ```
#
# Incoming Data:
#
# ```text
# salary = "abc"
# ```
#
# Delta Lake validates the schema and rejects invalid data.
#
# ### Benefits
#
# ✅ Better data quality
#
# ✅ Prevents bad data from being written
#
# ---
#
# ## 4. UPDATE, DELETE, and MERGE Support
#
# Traditional Parquet tables do not efficiently support:
#
# ```sql
# UPDATE
# DELETE
# MERGE
# ```
#
# Delta Lake supports all of them.
#
# ### Examples
#
# ```sql
# UPDATE sales
# SET amount = 2000
# WHERE id = 101;
# ```
#
# ```sql
# DELETE FROM sales
# WHERE id = 101;
# ```
#
# ```sql
# MERGE INTO customers
# USING updates
# ON customers.id = updates.id
# ```
#
# ---
#
# ## 5. Data Versioning
#
# Every write operation creates a new table version.
#
# Example:
#
# ```text
# Version 0
# Version 1
# Version 2
# Version 3
# ```
#
# Because all versions are tracked, Delta Lake can support Time Travel.
#
# ---
#
# # Delta Lake Folder Structure
#
# When data is stored as Delta:
#
# ```python
# df.write.format("delta").save("/sales")
# ```
#
# Folder Structure:
#
# ```text
# sales
# │
# ├── part-00000
# ├── part-00001
# ├── part-00002
# │
# └── _delta_log
#      ├── 000000.json
#      ├── 000001.json
#      ├── 000002.json
# ```
#
# ### Important
#
# ```text
# _delta_log
# ```
#
# is the heart of Delta Lake.
#
# It stores transaction history and metadata.
#
# ---
#
# # Delta Lake in Databricks
#
# Databricks Lakehouse architecture is built on:
#
# ```text
# Databricks
#       +
# Delta Lake
#       +
# Unity Catalog
# ```
#
# Together they provide:
#
# ✅ Reliable Storage
#
# ✅ Governance
#
# ✅ Security
#
# ✅ ACID Transactions
#
# ✅ Data Lineage
#
# ✅ Time Travel
#
# ---
#
# # Real-World Example
#
# Consider an e-commerce company processing:
#
# ```text
# Orders
# Payments
# Customers
# Shipments
# ```
#
# Requirements:
#
# ```text
# No Data Loss
# No Data Corruption
# Historical Data Access
# Reliable Reporting
# ```
#
# Delta Lake ensures:
#
# ✅ Safe concurrent operations
#
# ✅ Reliable updates and deletes
#
# ✅ Historical version recovery
#
# ✅ Enterprise-grade data consistency
#
# ---
#
# # Benefits of Delta Lake
#
# ✅ ACID Transactions
#
# ✅ Time Travel
#
# ✅ Schema Enforcement
#
# ✅ Schema Evolution
#
# ✅ Audit History
#
# ✅ Reliable Concurrent Writes
#
# ✅ UPDATE/DELETE/MERGE Support
#
# ✅ Better Data Quality
#
# ✅ Lakehouse Architecture Support
#
# ---
#
# # Interview Answer
#
# > Delta Lake is an open-source storage layer that brings Data Warehouse capabilities to a Data Lake. It provides ACID transactions, Time Travel, Schema Enforcement, Schema Evolution, Audit History, and support for UPDATE, DELETE, and MERGE operations. Delta Lake stores transaction metadata in the `_delta_log` folder, making data lakes more reliable, consistent, and suitable for enterprise analytics and Lakehouse architectures.

# %%
print("Interview QnA")

# %% [markdown]
# # Databricks Unity Catalog, Delta Lake, ACID & Time Travel Interview Questions and Answers
#
# ---
#
# # 1. What is Unity Catalog in Databricks?
#
# ### Answer
#
# Unity Catalog is Databricks' centralized governance solution used to manage:
#
# - Data Access
# - Security
# - Permissions
# - Auditing
# - Data Lineage
# - Data Discovery
#
# across all data assets from a single location.
#
# ---
#
# # 2. Why was Unity Catalog introduced?
#
# ### Answer
#
# Before Unity Catalog, each workspace had its own security and permission management.
#
# Unity Catalog provides:
#
# ✅ Centralized Governance
#
# ✅ Centralized Security
#
# ✅ Consistent Access Control
#
# ✅ Easier Administration
#
# across multiple Databricks workspaces.
#
# ---
#
# # 3. What is the hierarchy of Unity Catalog?
#
# ### Answer
#
# Unity Catalog follows a 3-level namespace:
#
# ```text
# Catalog
#    ↓
# Schema
#    ↓
# Table / View / Volume
# ```
#
# Example:
#
# ```text
# sales_catalog
#       ↓
# sales_schema
#       ↓
# orders
# ```
#
# Reference:
#
# ```sql
# SELECT *
# FROM sales_catalog.sales_schema.orders;
# ```
#
# ---
#
# # 4. What is a Catalog in Unity Catalog?
#
# ### Answer
#
# A Catalog is the top-level container in Unity Catalog.
#
# It contains:
#
# - Schemas
# - Tables
# - Views
# - Volumes
#
# Example:
#
# ```text
# sales_catalog
# marketing_catalog
# finance_catalog
# ```
#
# ---
#
# # 5. What is a Schema in Unity Catalog?
#
# ### Answer
#
# A Schema is a logical container inside a Catalog.
#
# It organizes related database objects.
#
# Example:
#
# ```text
# sales_catalog
#       ↓
# sales_schema
#       ↓
# orders
# customers
# products
# ```
#
# ---
#
# # 6. What is a Metastore?
#
# ### Answer
#
# A Metastore is the top-level governance container that stores metadata for all catalogs.
#
# Hierarchy:
#
# ```text
# Metastore
#    ↓
# Catalog
#    ↓
# Schema
#    ↓
# Table
# ```
#
# ---
#
# # 7. What are the key features of Unity Catalog?
#
# ### Answer
#
# ✅ Centralized Governance
#
# ✅ Data Lineage
#
# ✅ Fine-Grained Security
#
# ✅ Auditing
#
# ✅ Data Discovery
#
# ✅ Access Control
#
# ✅ Cross-Workspace Governance
#
# ---
#
# # 8. What is Fine-Grained Security?
#
# ### Answer
#
# Fine-Grained Security allows permissions at multiple levels.
#
# Examples:
#
# - Catalog Level
# - Schema Level
# - Table Level
# - Column Level
# - Row Level
#
# This allows precise control over who can access what data.
#
# ---
#
# # 9. What is Table-Level Security?
#
# ### Answer
#
# Users can be granted access to specific tables only.
#
# Example:
#
# User can access:
#
# ```text
# sales.orders
# ```
#
# but cannot access:
#
# ```text
# sales.customers
# ```
#
# ---
#
# # 10. What is Column-Level Security?
#
# ### Answer
#
# Column-Level Security restricts access to specific columns.
#
# Example:
#
# Table contains:
#
# ```text
# customer_id
# customer_name
# salary
# ```
#
# Users may see:
#
# ```text
# customer_id
# customer_name
# ```
#
# but not:
#
# ```text
# salary
# ```
#
# ---
#
# # 11. What is Row-Level Security?
#
# ### Answer
#
# Row-Level Security restricts access to specific rows.
#
# Example:
#
# North Region User can view:
#
# ```text
# North Region Records Only
# ```
#
# while South Region data remains hidden.
#
# ---
#
# # 12. What is Data Lineage?
#
# ### Answer
#
# Data Lineage tracks:
#
# - Data Source
# - Data Transformations
# - Data Consumers
#
# Example:
#
# ```text
# Raw Orders
#      ↓
# Silver Orders
#      ↓
# Gold Sales Report
# ```
#
# This allows complete tracking of data flow.
#
# ---
#
# # 13. Why is Data Lineage important?
#
# ### Answer
#
# Benefits:
#
# ✅ Easier Debugging
#
# ✅ Impact Analysis
#
# ✅ Governance
#
# ✅ Compliance
#
# ✅ Better Understanding of Data Flow
#
# ---
#
# # 14. What is Data Discovery?
#
# ### Answer
#
# Data Discovery allows users to search and find datasets easily.
#
# Users can discover:
#
# - Catalogs
# - Schemas
# - Tables
# - Owners
# - Descriptions
# - Tags
#
# ---
#
# # 15. What is Auditing in Unity Catalog?
#
# ### Answer
#
# Auditing records activities such as:
#
# - Who accessed data
# - Who modified data
# - Who granted permissions
# - Who revoked permissions
#
# Useful for security and compliance.
#
# ---
#
# # 16. Can Unity Catalog manage multiple workspaces?
#
# ### Answer
#
# Yes.
#
# One Unity Catalog can govern data across multiple Databricks workspaces using a centralized security model.
#
# ---
#
# # 17. How do you grant permissions in Unity Catalog?
#
# ### Answer
#
# Example:
#
# ```sql
# GRANT SELECT
# ON TABLE sales.orders
# TO analysts;
# ```
#
# The analysts group can read the table but cannot modify it.
#
# ---
#
# # 18. How can you improve table discoverability in Unity Catalog?
#
# ### Answer
#
# By using:
#
# - Table Descriptions
# - Schema Descriptions
# - Tags
# - Metadata
#
# Tags make searching and finding datasets easier.
#
# ---
#
# # 19. What is ACID?
#
# ### Answer
#
# ACID stands for:
#
# ```text
# A -> Atomicity
#
# C -> Consistency
#
# I -> Isolation
#
# D -> Durability
# ```
#
# These properties ensure reliable transactions.
#
# ---
#
# # 20. Which Databricks component provides ACID Transactions?
#
# ### Answer
#
# Delta Lake provides ACID transaction support.
#
# ---
#
# # 21. What is Atomicity?
#
# ### Answer
#
# Atomicity means:
#
# Either the entire transaction succeeds or the entire transaction fails.
#
# No partial updates are allowed.
#
# ---
#
# # 22. Give a real-world example of Atomicity.
#
# ### Answer
#
# Bank Transfer:
#
# ```text
# Account A -> -1000
#
# Account B -> +1000
# ```
#
# Possible outcomes:
#
# ✅ Both succeed
#
# OR
#
# ✅ Both rollback
#
# Never partial execution.
#
# ---
#
# # 23. What is Consistency?
#
# ### Answer
#
# Consistency ensures data remains valid before and after a transaction.
#
# Business rules and constraints must always be satisfied.
#
# ---
#
# # 24. Give an example of Consistency.
#
# ### Answer
#
# Rule:
#
# ```text
# salary > 0
# ```
#
# Invalid data:
#
# ```text
# salary = -1000
# ```
#
# should be prevented from violating integrity rules.
#
# ---
#
# # 25. What is Isolation?
#
# ### Answer
#
# Isolation ensures concurrent transactions do not interfere with each other.
#
# Users never see partially committed data.
#
# ---
#
# # 26. What problem does Isolation solve?
#
# ### Answer
#
# It prevents:
#
# - Dirty Reads
# - Inconsistent Reads
# - Concurrent Write Conflicts
#
# ---
#
# # 27. What is Durability?
#
# ### Answer
#
# Durability guarantees that once a transaction is committed, it remains permanently stored.
#
# Even after:
#
# - Cluster Failure
# - Node Failure
# - System Restart
#
# the committed data remains safe.
#
# ---
#
# # 28. Why are ACID properties important?
#
# ### Answer
#
# Without ACID:
#
# ❌ Data Corruption
#
# ❌ Partial Updates
#
# ❌ Inconsistent Reports
#
# ❌ Concurrency Problems
#
# With ACID:
#
# ✅ Reliable Data
#
# ✅ Safe Writes
#
# ✅ Consistent Analytics
#
# ---
#
# # 29. Which Delta Lake operations are ACID compliant?
#
# ### Answer
#
# ```sql
# INSERT
# UPDATE
# DELETE
# MERGE
# ```
#
# All are ACID compliant in Delta Lake.
#
# ---
#
# # 30. What is Time Travel in Databricks?
#
# ### Answer
#
# Time Travel is a Delta Lake feature that allows users to access historical versions of a table.
#
# It enables viewing or restoring previous table states.
#
# ---
#
# # 31. Why is Time Travel useful?
#
# ### Answer
#
# ✅ Data Recovery
#
# ✅ Historical Analysis
#
# ✅ Auditing
#
# ✅ Debugging
#
# ✅ Reproducing Reports
#
# ---
#
# # 32. How does Time Travel work?
#
# ### Answer
#
# Every write operation creates a new table version.
#
# Example:
#
# ```text
# Version 0
#
# Version 1
#
# Version 2
#
# Version 3
# ```
#
# Delta stores these versions in transaction logs.
#
# ---
#
# # 33. How can you view table history?
#
# ### Answer
#
# ```sql
# DESCRIBE HISTORY customers;
# ```
#
# This displays:
#
# - Version
# - Timestamp
# - User
# - Operation
#
# ---
#
# # 34. How do you query a previous version?
#
# ### Answer
#
# ```sql
# SELECT *
# FROM customers
# VERSION AS OF 5;
# ```
#
# Returns data exactly as it existed in Version 5.
#
# ---
#
# # 35. How do you query data by timestamp?
#
# ### Answer
#
# ```sql
# SELECT *
# FROM customers
# TIMESTAMP AS OF '2025-01-01 10:00:00';
# ```
#
# Returns data as it existed at that time.
#
# ---
#
# # 36. How do you restore a previous version?
#
# ### Answer
#
# ```sql
# RESTORE TABLE customers
# TO VERSION AS OF 10;
# ```
#
# Restores the table to Version 10.
#
# ---
#
# # 37. Why is Time Travel compared to Git?
#
# ### Answer
#
# Similar to Git:
#
# - Maintains history
# - Keeps versions
# - Allows rollback
# - Allows reconstruction of previous states
#
# ---
#
# # 38. What is Delta Lake?
#
# ### Answer
#
# Delta Lake is an open-source storage layer that brings Data Warehouse capabilities to Data Lakes.
#
# Features include:
#
# - ACID Transactions
# - Time Travel
# - Schema Enforcement
# - Schema Evolution
# - Audit History
# - MERGE Support
#
# ---
#
# # 39. Why was Delta Lake introduced?
#
# ### Answer
#
# Traditional Data Lakes lacked:
#
# - ACID Transactions
# - Versioning
# - Updates
# - Deletes
# - Reliable Concurrent Writes
#
# Delta Lake addresses these limitations.
#
# ---
#
# # 40. What problems exist in plain Parquet Data Lakes?
#
# ### Answer
#
# ❌ No ACID Transactions
#
# ❌ No Time Travel
#
# ❌ Concurrent Write Issues
#
# ❌ No Transaction History
#
# ❌ Limited Update/Delete Support
#
# ---
#
# # 41. What is _delta_log?
#
# ### Answer
#
# `_delta_log` is the transaction log directory used by Delta Lake.
#
# It is the most important component of Delta Lake.
#
# ---
#
# # 42. What information is stored in _delta_log?
#
# ### Answer
#
# It stores:
#
# - Transaction History
# - Commit Information
# - Metadata
# - Schema Details
# - Table Versions
#
# ---
#
# # 43. Why is _delta_log called the heart of Delta Lake?
#
# ### Answer
#
# Because features such as:
#
# - ACID Transactions
# - Time Travel
# - Auditing
# - Recovery
#
# depend on the transaction log.
#
# ---
#
# # 44. What is Schema Enforcement in Delta Lake?
#
# ### Answer
#
# Schema Enforcement validates incoming data before writing.
#
# Invalid data is rejected.
#
# Example:
#
# Expected:
#
# ```text
# salary -> Double
# ```
#
# Received:
#
# ```text
# salary -> "abc"
# ```
#
# Write operation fails.
#
# ---
#
# # 45. What is Schema Evolution?
#
# ### Answer
#
# Schema Evolution allows a Delta table schema to evolve by adding compatible columns when required.
#
# Useful for handling changing source systems.
#
# ---
#
# # 46. Does Delta Lake support UPDATE and DELETE?
#
# ### Answer
#
# Yes.
#
# Examples:
#
# ```sql
# UPDATE customers
# SET city = 'Bangalore'
# WHERE id = 101;
# ```
#
# ```sql
# DELETE FROM customers
# WHERE id = 101;
# ```
#
# ---
#
# # 47. What is MERGE in Delta Lake?
#
# ### Answer
#
# MERGE combines INSERT, UPDATE, and DELETE operations into a single transaction.
#
# Often used for UPSERT operations.
#
# Example:
#
# ```sql
# MERGE INTO target
# USING source
# ON target.id = source.id
# ```
#
# ---
#
# # 48. How does Delta Lake support concurrent users?
#
# ### Answer
#
# Through ACID Transactions and transactional logging.
#
# Multiple users can safely read and write simultaneously.
#
# ---
#
# # 49. How does Delta Lake fit into the Databricks Lakehouse Architecture?
#
# ### Answer
#
# ```text
# Databricks
#       +
# Delta Lake
#       +
# Unity Catalog
# ```
#
# Provides:
#
# ✅ Governance
#
# ✅ Security
#
# ✅ ACID Transactions
#
# ✅ Lineage
#
# ✅ Time Travel
#
# ✅ Reliable Storage
#
# ---
#
# # 50. Complete Interview Answer: Delta Lake
#
# ### Answer
#
# Delta Lake is an open-source storage layer that brings ACID transactions, schema enforcement, schema evolution, audit history, UPDATE, DELETE, MERGE, and Time Travel capabilities to Data Lakes. It maintains transaction history through the `_delta_log` and acts as the foundation of Databricks Lakehouse architecture by providing reliable, scalable, and consistent data processing.
#
# ---
#
# # Quick Revision
#
# ```text
# UNITY CATALOG
# -------------
# Central Governance Layer
#
# Hierarchy:
# Metastore
#    ↓
# Catalog
#    ↓
# Schema
#    ↓
# Table/View/Volume
#
# Features:
# - Security
# - Permissions
# - Lineage
# - Auditing
# - Data Discovery
#
# --------------------------------
#
# ACID
# -----
#
# Atomicity
# = All or Nothing
#
# Consistency
# = Valid Data State
#
# Isolation
# = No Transaction Interference
#
# Durability
# = Permanent Storage
#
# Provided By:
# Delta Lake
#
# --------------------------------
#
# TIME TRAVEL
# -----------
#
# View Older Versions
#
# Commands:
#
# DESCRIBE HISTORY table
#
# VERSION AS OF
#
# TIMESTAMP AS OF
#
# RESTORE TABLE
#
# Benefits:
# - Recovery
# - Auditing
# - Debugging
# - Historical Analysis
#
# --------------------------------
#
# DELTA LAKE
# ----------
#
# Open Source Storage Layer
#
# Features:
#
# - ACID Transactions
# - Time Travel
# - Schema Enforcement
# - Schema Evolution
# - Audit History
# - UPDATE
# - DELETE
# - MERGE
#
# --------------------------------
#
# _delta_log
# -----------
#
# Heart of Delta Lake
#
# Stores:
# - Transactions
# - Versions
# - Metadata
# - History
#
# --------------------------------
#
# Databricks Lakehouse
#
# Databricks
# +
# Delta Lake
# +
# Unity Catalog
# ```
